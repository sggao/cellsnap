# %%
import muse_sc as muse
import phenograph
from sklearn.decomposition import PCA
import numpy as np
from sklearn.metrics.cluster import adjusted_rand_score
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import tensorflow as tf
tf.get_logger().setLevel('ERROR')
np.random.seed(0)
# Out:
# WARNING:tensorflow:From /home/bokai/miniconda3/envs/muse/lib/python3.6/site-packages/tensorflow/python/compat/v2_compat.py:101: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
import pandas as pd

###### process protein modality

data1 = pd.read_csv("../data/features_and_metadata.csv")
features_names = [
        'CD2', 'CD56',
        'CD20', 'CD30', 'CD31', 'CD4', 
        'CD57',  'CD7', 'CD8',
        'Granzyme.B','FoxP3', 'CD11c', 'CD16', 'CD206', 'CD163', 'CD68', 'CD15', 'CD11b',
        'MCT', 'Cytokeratin', 
        'Podoplanin', 'a.SMA'
    ]
dataa = data1[features_names]
#dataa = dataa.drop('nucl',axis = 1)
#dataa = data1

## change to scaled version 
from scipy.stats import zscore
dataa = dataa.apply(zscore)
dataa = dataa

####### process imaging modality

datab_full = np.load('../data/images/Inception_img_feature_chlcodex_full.npy') # full data size version

###### this is pca on feature mod and image mod

latent_dim = 20
view_a_feature = PCA(n_components=latent_dim).fit_transform(dataa)
### this is pca on img mod
latent_dim = 100
view_b_feature = PCA(n_components=latent_dim).fit_transform(datab_full)
### then default clustering

# already finished running
view_a_label, _, _ = phenograph.cluster(view_a_feature, n_jobs = 16)
view_b_label, _, _ = phenograph.cluster(view_b_feature, n_jobs = 16)
# Out:
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 245.41244220733643 seconds
# Jaccard graph constructed in 55.50883913040161 seconds
# Wrote graph to binary file in 9.867979288101196 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.858122
# After 4 runs, maximum modularity is Q = 0.860914
# Louvain completed 24 runs in 160.12310242652893 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 475.82967734336853 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 273.0466215610504 seconds
# Jaccard graph constructed in 52.369524002075195 seconds
# Wrote graph to binary file in 8.484092950820923 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.670653
# Louvain completed 21 runs in 100.2457869052887 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 440.96811962127686 seconds

# %%
dataa.shape
# Out:
# (143730, 22)

# %%
view_a_label = view_a_label[:-1] # last image was missing lets discard this cell
np.save('../data/musechlcdxfull_a_label.npy', view_a_label)
np.save('../data/musechlcdxfull_b_label.npy', view_b_label)
print([view_a_label.shape, view_b_label.shape])
# Out:
# [(143729,), (143729,)]

# %%
#view_a_label = view_a_label[:-1]
view_a_label = np.load('../data/musechlcdxfull_a_label.npy')
view_b_label = np.load('../data/musechlcdxfull_b_label.npy')
print([view_a_label.shape, view_b_label.shape])
# Out:
# [(143729,), (143729,)]

# %% [markdown]
# ### change original muse function phenograph cpu allocation too many issue

# %%
import numpy as np
from muse_sc.muse_architecture import structured_embedding
from scipy.spatial.distance import pdist
import phenograph
import tensorflow.compat.v1 as tf

tf.disable_v2_behavior()

def muse_fit_predict(data_x,
                     data_y,
                     label_x,
                     label_y,
                     latent_dim=100,
                     n_epochs=500,
                     lambda_regul=5,
                     lambda_super=5):
    """
        MUSE model fitting and predicting:
          This function is used to train the MUSE model on multi-modality data

        Parameters:
          data_x:       input for transcript modality; matrix of  n * p, where n = number of cells, p = number of genes.
          data_y:       input for morphological modality; matrix of n * q, where n = number of cells, q is the feature dimension.
          label_x:      initial reference cluster label for transcriptional modality.
          label_y:      inital reference cluster label for morphological modality.
          latent_dim:   feature dimension of joint latent representation.
          n_epochs:     maximal epoch used in training.
          lambda_regul: weight for regularization term in the loss function.
          lambda_super: weight for supervised learning loss in the loss function.

        Output:
          latent:       joint latent representation learned by MUSE.
          reconstruct_x:reconstructed feature matrix corresponding to input data_x.
          reconstruct_y:reconstructed feature matrix corresponding to input data_y.
          latent_x:     modality-specific latent representation corresponding to data_x.
          latent_y:     modality-specific latent representation corresponding to data_y.

        Feng Bao @ Altschuler & Wu Lab @ UCSF 2022.
        Software provided as is under MIT License.
    """

    """ initial parameter setting """
    # parameter setting for neural network
    n_hidden = 128  # number of hidden node in neural network
    learn_rate = 1e-4  # learning rate in the optimization
    batch_size = 64  # number of cells in the training batch
    n_epochs_init = 200  # number of training epoch in model initialization
    print_epochs = 50  # epoch interval to display the current training loss
    cluster_update_epoch = 200  # epoch interval to update modality-specific clusters

    # read data-specific parameters from inputs
    feature_dim_x = data_x.shape[1]
    feature_dim_y = data_y.shape[1]
    n_sample = data_x.shape[0]

    # GPU configuration
    # config = tf.ConfigProto()
    # config.gpu_options.allow_growth = True

    """ construct computation graph using TensorFlow """
    tf.reset_default_graph()

    # raw data from two modalities
    x = tf.placeholder(tf.float32, shape=[None, feature_dim_x], name='input_x')
    y = tf.placeholder(tf.float32, shape=[None, feature_dim_y], name='input_y')

    # labels inputted for references
    ref_label_x = tf.placeholder(tf.float32, shape=[None], name='ref_label_x')
    ref_label_y = tf.placeholder(tf.float32, shape=[None], name='ref_label_y')

    # hyperparameter in triplet loss
    triplet_lambda = tf.placeholder(tf.float32, name='triplet_lambda')
    triplet_margin = tf.placeholder(tf.float32, name='triplet_margin')

    # network architecture
    z, x_hat, y_hat, encode_x, encode_y, loss, \
    reconstruction_error, weight_penalty, \
    trip_loss_x, trip_loss_y = structured_embedding(x,
                                                    y,
                                                    ref_label_x,
                                                    ref_label_y,
                                                    latent_dim,
                                                    triplet_margin,
                                                    n_hidden,
                                                    lambda_regul,
                                                    triplet_lambda)
    # optimization operator
    train_op = tf.train.AdamOptimizer(learn_rate).minimize(loss)
    print('++++++++++ MUSE for multi-modality single-cell analysis ++++++++++')
    """ MUSE optimization """
    total_batch = int(n_sample / batch_size)

    with tf.Session() as sess:

        """ initialization of autoencoder architecture for MUSE """
        print('MUSE initialization')
        # global parameter initialization
        sess.run(tf.global_variables_initializer(), feed_dict={triplet_lambda: 0,
                                                               triplet_margin: 0})

        for epoch in range(n_epochs_init):
            # randomly permute samples
            random_idx = np.random.permutation(n_sample)
            data_train_x = data_x[random_idx, :]
            data_train_y = data_y[random_idx, :]

            for i in range(total_batch):
                # input data batches
                offset = (i * batch_size) % (n_sample)
                batch_x_input = data_train_x[offset:(offset + batch_size), :]
                batch_y_input = data_train_y[offset:(offset + batch_size), :]

                # initialize parameters without self-supervised loss (triplet_lambda=0)
                sess.run(train_op,
                         feed_dict={x: batch_x_input,
                                    y: batch_y_input,
                                    ref_label_x: np.zeros(batch_x_input.shape[0]),
                                    ref_label_y: np.zeros(batch_y_input.shape[0]),
                                    triplet_lambda: 0,
                                    triplet_margin: 0})

            # calculate and print loss terms for current epoch
            if epoch % print_epochs == 0:
                L_total, L_reconstruction, L_weight = \
                    sess.run((loss, reconstruction_error, weight_penalty),
                             feed_dict={x: data_train_x,
                                        y: data_train_y,
                                        ref_label_x: np.zeros(data_train_x.shape[0]),  # no use as triplet_lambda=0
                                        ref_label_y: np.zeros(data_train_y.shape[0]),  # no use as triplet_lambda=0
                                        triplet_lambda: 0,
                                        triplet_margin: 0})

                print(
                    "epoch: %d, \t total loss: %03.5f,\t reconstruction loss: %03.5f,\t sparse penalty: %03.5f"
                    % (epoch, L_total, L_reconstruction, L_weight))

        # estimate the margin for the triplet loss
        latent, reconstruct_x, reconstruct_y = \
            sess.run((z, x_hat, y_hat),
                     feed_dict={x: data_x,
                                y: data_y,
                                ref_label_x: np.zeros(data_x.shape[0]),
                                ref_label_y: np.zeros(data_y.shape[0]),
                                triplet_lambda: 0,
                                triplet_margin: 0})
        latent_pd_matrix = pdist(latent, 'euclidean')
        latent_pd_sort = np.sort(latent_pd_matrix)
        select_top_n = np.int(latent_pd_sort.size * 0.2)
        margin_estimate = np.median(latent_pd_sort[-select_top_n:]) - np.median(latent_pd_sort[:select_top_n])

        # refine MUSE parameters with reference labels and triplet losses
        for epoch in range(n_epochs_init):
            # randomly permute samples
            random_idx = np.random.permutation(n_sample)
            data_train_x = data_x[random_idx, :]
            data_train_y = data_y[random_idx, :]
            label_train_x = label_x[random_idx]
            label_train_y = label_y[random_idx]

            for i in range(total_batch):
                # data batches
                offset = (i * batch_size) % (n_sample)
                batch_x_input = data_train_x[offset:(offset + batch_size), :]
                batch_y_input = data_train_y[offset:(offset + batch_size), :]
                label_x_input = label_train_x[offset:(offset + batch_size)]
                label_y_input = label_train_y[offset:(offset + batch_size)]

                # refine parameters
                sess.run(train_op,
                         feed_dict={x: batch_x_input,
                                    y: batch_y_input,
                                    ref_label_x: label_x_input,
                                    ref_label_y: label_y_input,
                                    triplet_lambda: lambda_super,
                                    triplet_margin: margin_estimate})

            # calculate loss on all input data for current epoch
            if epoch % print_epochs == 0:
                L_total, L_reconstruction, L_weight, L_trip_x, L_trip_y = \
                    sess.run((loss, reconstruction_error, weight_penalty, trip_loss_x, trip_loss_y),
                             feed_dict={x: data_train_x,
                                        y: data_train_y,
                                        ref_label_x: label_train_x,
                                        ref_label_y: label_train_y,
                                        triplet_lambda: lambda_super,
                                        triplet_margin: margin_estimate})

                print(
                    "epoch: %d, \t total loss: %03.5f,\t reconstruction loss: %03.5f,\t sparse penalty: %03.5f,\t x triplet: %03.5f,\t y triplet: %03.5f"
                    % (epoch, L_total, L_reconstruction, L_weight, L_trip_x, L_trip_y))

        # update cluster labels based modality-specific latents
        latent_x, latent_y = \
            sess.run((encode_x, encode_y),
                     feed_dict={x: data_x,
                                y: data_y,
                                ref_label_x: label_x,
                                ref_label_y: label_y,
                                triplet_lambda: lambda_super,
                                triplet_margin: margin_estimate})

        # update cluster labels using PhenoGraph
        label_x_update, _, _ = phenograph.cluster(latent_x, n_jobs= 2)
        label_y_update, _, _ = phenograph.cluster(latent_y, n_jobs= 2)
        print('Finish initialization of MUSE')

        ''' Training of MUSE '''
        for epoch in range(n_epochs):
            # randomly permute samples
            random_idx = np.random.permutation(n_sample)
            data_train_x = data_x[random_idx, :]
            data_train_y = data_y[random_idx, :]
            label_train_x = label_x_update[random_idx]
            label_train_y = label_y_update[random_idx]

            # loop over all batches
            for i in range(total_batch):
                # batch data
                offset = (i * batch_size) % (n_sample)
                batch_x_input = data_train_x[offset:(offset + batch_size), :]
                batch_y_input = data_train_y[offset:(offset + batch_size), :]
                batch_label_x_input = label_train_x[offset:(offset + batch_size)]
                batch_label_y_input = label_train_y[offset:(offset + batch_size)]

                sess.run(train_op,
                         feed_dict={x: batch_x_input,
                                    y: batch_y_input,
                                    ref_label_x: batch_label_x_input,
                                    ref_label_y: batch_label_y_input,
                                    triplet_lambda: lambda_super,
                                    triplet_margin: margin_estimate})

            # calculate and print losses on whole training dataset
            if epoch % print_epochs == 0:
                L_total, L_reconstruction, L_weight, L_trip_x, L_trip_y = \
                    sess.run((loss, reconstruction_error, weight_penalty, trip_loss_x, trip_loss_y),
                             feed_dict={x: data_train_x,
                                        y: data_train_y,
                                        ref_label_x: label_train_x,
                                        ref_label_y: label_train_y,
                                        triplet_lambda: lambda_super,
                                        triplet_margin: margin_estimate})
                # print cost every epoch
                print(
                    "epoch: %d, \t total loss: %03.5f,\t reconstruction loss: %03.5f,\t sparse penalty: %03.5f,\t x triplet loss: %03.5f,\t y triplet loss: %03.5f"
                    % (epoch, L_total, L_reconstruction, L_weight, L_trip_x, L_trip_y))

            # update cluster labels based on new modality-specific latent representations
            if epoch % cluster_update_epoch == 0:
                latent_x, latent_y = \
                    sess.run((encode_x, encode_y),
                             feed_dict={x: data_x,
                                        y: data_y,
                                        ref_label_x: label_x,
                                        ref_label_y: label_y,
                                        triplet_lambda: lambda_super,
                                        triplet_margin: margin_estimate})

                # use PhenoGraph to obtain cluster label
                label_x_update, _, _ = phenograph.cluster(latent_x, n_jobs= 2)
                label_y_update, _, _ = phenograph.cluster(latent_y, n_jobs= 2)

        """ MUSE output """
        latent, reconstruct_x, reconstruct_y, latent_x, latent_y = \
            sess.run((z, x_hat, y_hat, encode_x, encode_y),
                     feed_dict={x: data_x,
                                y: data_y,
                                ref_label_x: label_x,  # no effects to representations
                                ref_label_y: label_y,  # no effects to representations
                                triplet_lambda: lambda_super,
                                triplet_margin: margin_estimate})

        print('++++++++++ MUSE completed ++++++++++')

    return latent, reconstruct_x, reconstruct_y, latent_x, latent_y

# %%
## this is just for testing

################################# loop batch version, random sample
for i in range(5):

  np.random.seed(i)
  indices = np.random.choice(datab_full.shape[0], 10000, replace=False)
  dataa_sub = dataa.iloc[indices,:]
  datab_sub = datab_full[indices,:]
  view_a_label_sub = view_a_label[indices]
  view_b_label_sub = view_b_label[indices]

  muse_feature, reconstruct_x, reconstruct_y, \
    latent_x, latent_y = muse_fit_predict(dataa_sub.to_numpy(),
                                          datab_sub,
                                          view_a_label_sub,
                                          view_b_label_sub,
                                          latent_dim=30,
                                          n_epochs=500,
                                          lambda_regul=5,
                                          lambda_super=5)
  name = 'batch_' + str(i) + '.npy'
  np.save('../data/muse_469full_embedding_' + name, muse_feature)
# Out:
# ++++++++++ MUSE for multi-modality single-cell analysis ++++++++++
# MUSE initialization
# epoch: 0, 	 total loss: 1523.49414,	 reconstruction loss: 1229.62915,	 sparse penalty: 58.77299
# epoch: 50, 	 total loss: 841.77588,	 reconstruction loss: 694.78754,	 sparse penalty: 29.39767
# epoch: 100, 	 total loss: 705.31390,	 reconstruction loss: 647.00122,	 sparse penalty: 11.66253
# epoch: 150, 	 total loss: 647.97119,	 reconstruction loss: 633.75745,	 sparse penalty: 2.84275
# epoch: 0, 	 total loss: 802.07434,	 reconstruction loss: 691.57196,	 sparse penalty: 0.41859,	 x triplet: 11.05236,	 y triplet: 10.62953
# epoch: 50, 	 total loss: 718.78711,	 reconstruction loss: 636.20740,	 sparse penalty: 0.55731,	 x triplet: 8.03356,	 y triplet: 7.92508
# epoch: 100, 	 total loss: 711.66370,	 reconstruction loss: 632.14392,	 sparse penalty: 0.41956,	 x triplet: 7.78116,	 y triplet: 7.70323
# epoch: 150, 	 total loss: 707.21643,	 reconstruction loss: 629.25079,	 sparse penalty: 0.34147,	 x triplet: 7.65914,	 y triplet: 7.59253
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 1.5714406967163086 seconds
# Jaccard graph constructed in 10.931543827056885 seconds
# Wrote graph to binary file in 0.750990629196167 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.85342
# After 2 runs, maximum modularity is Q = 0.85494
# Louvain completed 22 runs in 8.965057373046875 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 30.777803659439087 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 2.117755889892578 seconds
# Jaccard graph constructed in 11.040194034576416 seconds
# Wrote graph to binary file in 0.9114723205566406 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.598232
# Louvain completed 21 runs in 9.225244760513306 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 32.29442286491394 seconds
# Finish initialization of MUSE
# epoch: 0, 	 total loss: 704.84253,	 reconstruction loss: 627.77319,	 sparse penalty: 0.29551,	 x triplet loss: 7.57885,	 y triplet loss: 7.53951
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 2.2601959705352783 seconds
# Jaccard graph constructed in 11.125582933425903 seconds
# Wrote graph to binary file in 0.8777580261230469 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.852837
# After 5 runs, maximum modularity is Q = 0.854027
# Louvain completed 25 runs in 10.092222929000854 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 33.41950297355652 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 1.8225228786468506 seconds
# Jaccard graph constructed in 11.199826717376709 seconds
# Wrote graph to binary file in 0.8471379280090332 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.589298
# After 2 runs, maximum modularity is Q = 0.593185
# After 3 runs, maximum modularity is Q = 0.599117
# Louvain completed 23 runs in 11.81606125831604 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 34.97452354431152 seconds
# epoch: 50, 	 total loss: 703.04456,	 reconstruction loss: 626.75214,	 sparse penalty: 0.26943,	 x triplet loss: 7.51632,	 y triplet loss: 7.47273
# epoch: 100, 	 total loss: 701.77124,	 reconstruction loss: 625.94550,	 sparse penalty: 0.24594,	 x triplet loss: 7.48017,	 y triplet loss: 7.43904
# epoch: 150, 	 total loss: 701.08020,	 reconstruction loss: 625.58173,	 sparse penalty: 0.22735,	 x triplet loss: 7.45514,	 y triplet loss: 7.41720
# epoch: 200, 	 total loss: 700.52936,	 reconstruction loss: 625.30273,	 sparse penalty: 0.21246,	 x triplet loss: 7.43348,	 y triplet loss: 7.39938
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 2.2760581970214844 seconds
# Jaccard graph constructed in 11.534981489181519 seconds
# Wrote graph to binary file in 0.8961656093597412 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.849916
# Louvain completed 21 runs in 8.143360614776611 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 32.450249433517456 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 2.051915168762207 seconds
# Jaccard graph constructed in 12.156038999557495 seconds
# Wrote graph to binary file in 0.8332931995391846 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.59792
# Louvain completed 21 runs in 9.333055973052979 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 34.17601919174194 seconds
# epoch: 250, 	 total loss: 699.29126,	 reconstruction loss: 624.33893,	 sparse penalty: 0.20711,	 x triplet loss: 7.40239,	 y triplet loss: 7.38097
# epoch: 300, 	 total loss: 698.06165,	 reconstruction loss: 623.30493,	 sparse penalty: 0.19657,	 x triplet loss: 7.38811,	 y triplet loss: 7.36667
# epoch: 350, 	 total loss: 698.05408,	 reconstruction loss: 623.46503,	 sparse penalty: 0.18892,	 x triplet loss: 7.37489,	 y triplet loss: 7.35400
# epoch: 400, 	 total loss: 697.44678,	 reconstruction loss: 623.00183,	 sparse penalty: 0.18105,	 x triplet loss: 7.36416,	 y triplet loss: 7.34378
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 2.080127239227295 seconds
# Jaccard graph constructed in 12.447417259216309 seconds
# Wrote graph to binary file in 1.029567003250122 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.841874
# After 12 runs, maximum modularity is Q = 0.843202
# Louvain completed 32 runs in 12.908492803573608 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 38.434365034103394 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 2.1414828300476074 seconds
# Jaccard graph constructed in 12.616402626037598 seconds
# Wrote graph to binary file in 0.7607550621032715 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.599612
# After 3 runs, maximum modularity is Q = 0.601973
# After 9 runs, maximum modularity is Q = 0.604055
# Louvain completed 29 runs in 14.943246364593506 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 40.68928027153015 seconds
# epoch: 450, 	 total loss: 696.22382,	 reconstruction loss: 621.90393,	 sparse penalty: 0.17452,	 x triplet loss: 7.35531,	 y triplet loss: 7.33415
# ++++++++++ MUSE completed ++++++++++
# ++++++++++ MUSE for multi-modality single-cell analysis ++++++++++
# MUSE initialization
# epoch: 0, 	 total loss: 1483.48792,	 reconstruction loss: 1180.44189,	 sparse penalty: 60.60920
# epoch: 50, 	 total loss: 860.38245,	 reconstruction loss: 702.09943,	 sparse penalty: 31.65660
# epoch: 100, 	 total loss: 717.92749,	 reconstruction loss: 647.25244,	 sparse penalty: 14.13501
# epoch: 150, 	 total loss: 664.72260,	 reconstruction loss: 636.39618,	 sparse penalty: 5.66528
# epoch: 0, 	 total loss: 807.69690,	 reconstruction loss: 697.24921,	 sparse penalty: 1.94476,	 x triplet: 10.28241,	 y triplet: 9.86236
# epoch: 50, 	 total loss: 718.65125,	 reconstruction loss: 641.27167,	 sparse penalty: 0.77639,	 x triplet: 7.38731,	 y triplet: 7.31221
# epoch: 100, 	 total loss: 711.20398,	 reconstruction loss: 638.26947,	 sparse penalty: 0.42472,	 x triplet: 7.10464,	 y triplet: 7.05755
# epoch: 150, 	 total loss: 707.91315,	 reconstruction loss: 636.62952,	 sparse penalty: 0.33969,	 x triplet: 6.97921,	 y triplet: 6.93781
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 1.9758758544921875 seconds
# Jaccard graph constructed in 13.42635202407837 seconds
# Wrote graph to binary file in 0.8646225929260254 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.855997
# After 10 runs, maximum modularity is Q = 0.857343
# Louvain completed 30 runs in 12.759981870651245 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 39.897849321365356 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 1.8068718910217285 seconds
# Jaccard graph constructed in 13.80121660232544 seconds
# Wrote graph to binary file in 1.0081920623779297 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.586869
# After 2 runs, maximum modularity is Q = 0.590486
# After 9 runs, maximum modularity is Q = 0.592571
# After 26 runs, maximum modularity is Q = 0.594567
# Louvain completed 46 runs in 23.982773303985596 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 51.70225191116333 seconds
# Finish initialization of MUSE
# epoch: 0, 	 total loss: 705.80750,	 reconstruction loss: 635.43945,	 sparse penalty: 0.29391,	 x triplet loss: 6.89605,	 y triplet loss: 6.88364
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 2.1798479557037354 seconds
# Jaccard graph constructed in 13.863373756408691 seconds
# Wrote graph to binary file in 0.9446170330047607 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.854986
# After 2 runs, maximum modularity is Q = 0.857191
# Louvain completed 22 runs in 10.337036371231079 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 38.721848487854004 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 2.116903066635132 seconds
# Jaccard graph constructed in 13.812784910202026 seconds
# Wrote graph to binary file in 0.9233677387237549 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.596382
# After 8 runs, maximum modularity is Q = 0.597447
# After 11 runs, maximum modularity is Q = 0.601087
# Louvain completed 31 runs in 16.635825634002686 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 44.93446183204651 seconds
# epoch: 50, 	 total loss: 703.73108,	 reconstruction loss: 634.24988,	 sparse penalty: 0.27510,	 x triplet loss: 6.81918,	 y triplet loss: 6.80196
# epoch: 100, 	 total loss: 702.79559,	 reconstruction loss: 633.80890,	 sparse penalty: 0.24983,	 x triplet loss: 6.78202,	 y triplet loss: 6.76549
# epoch: 150, 	 total loss: 702.44305,	 reconstruction loss: 633.82166,	 sparse penalty: 0.23023,	 x triplet loss: 6.75326,	 y triplet loss: 6.74078
# epoch: 200, 	 total loss: 701.65314,	 reconstruction loss: 633.32446,	 sparse penalty: 0.21411,	 x triplet loss: 6.73115,	 y triplet loss: 6.72047
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 1.809539556503296 seconds
# Jaccard graph constructed in 14.465286254882812 seconds
# Wrote graph to binary file in 0.9682431221008301 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.853076
# After 10 runs, maximum modularity is Q = 0.855416
# Louvain completed 30 runs in 13.149543762207031 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 42.14104413986206 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 2.1102898120880127 seconds
# Jaccard graph constructed in 14.6972074508667 seconds
# Wrote graph to binary file in 0.9294533729553223 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.600786
# After 15 runs, maximum modularity is Q = 0.607694
# Louvain completed 35 runs in 17.045142889022827 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 46.80776405334473 seconds
# epoch: 250, 	 total loss: 701.60889,	 reconstruction loss: 633.52222,	 sparse penalty: 0.20232,	 x triplet loss: 6.71179,	 y triplet loss: 6.70322
# epoch: 300, 	 total loss: 699.45538,	 reconstruction loss: 631.57025,	 sparse penalty: 0.19190,	 x triplet loss: 6.69636,	 y triplet loss: 6.68877
# epoch: 350, 	 total loss: 698.64832,	 reconstruction loss: 630.92316,	 sparse penalty: 0.18295,	 x triplet loss: 6.68450,	 y triplet loss: 6.67757
# epoch: 400, 	 total loss: 698.73590,	 reconstruction loss: 631.16919,	 sparse penalty: 0.17558,	 x triplet loss: 6.67305,	 y triplet loss: 6.66473
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 2.309792995452881 seconds
# Jaccard graph constructed in 15.142863988876343 seconds
# Wrote graph to binary file in 1.1544413566589355 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.842905
# After 10 runs, maximum modularity is Q = 0.844343
# Louvain completed 30 runs in 13.86020803451538 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 44.5498685836792 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 2.003575086593628 seconds
# Jaccard graph constructed in 15.171953678131104 seconds
# Wrote graph to binary file in 0.8528168201446533 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.601496
# After 3 runs, maximum modularity is Q = 0.60774
# Louvain completed 23 runs in 12.684877872467041 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 44.48989391326904 seconds
# epoch: 450, 	 total loss: 697.86096,	 reconstruction loss: 630.44019,	 sparse penalty: 0.17056,	 x triplet loss: 6.66130,	 y triplet loss: 6.65228
# ++++++++++ MUSE completed ++++++++++
# ++++++++++ MUSE for multi-modality single-cell analysis ++++++++++
# MUSE initialization
# epoch: 0, 	 total loss: 1573.69641,	 reconstruction loss: 1286.11255,	 sparse penalty: 57.51677
# epoch: 50, 	 total loss: 845.70435,	 reconstruction loss: 703.61456,	 sparse penalty: 28.41795
# epoch: 100, 	 total loss: 699.17731,	 reconstruction loss: 644.09296,	 sparse penalty: 11.01687
# epoch: 150, 	 total loss: 648.39319,	 reconstruction loss: 633.84009,	 sparse penalty: 2.91062
# epoch: 0, 	 total loss: 791.75610,	 reconstruction loss: 691.88092,	 sparse penalty: 0.63539,	 x triplet: 9.87581,	 y triplet: 9.46383
# epoch: 50, 	 total loss: 710.18964,	 reconstruction loss: 637.39941,	 sparse penalty: 0.56853,	 x triplet: 7.04385,	 y triplet: 6.94565
# epoch: 100, 	 total loss: 703.85400,	 reconstruction loss: 634.40265,	 sparse penalty: 0.39474,	 x triplet: 6.78083,	 y triplet: 6.71468
# epoch: 150, 	 total loss: 700.22388,	 reconstruction loss: 632.42670,	 sparse penalty: 0.31375,	 x triplet: 6.64866,	 y triplet: 6.59703
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 1.9442484378814697 seconds
# Jaccard graph constructed in 16.919131994247437 seconds
# Wrote graph to binary file in 0.9174096584320068 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.851996
# After 9 runs, maximum modularity is Q = 0.853009
# Louvain completed 29 runs in 13.812788248062134 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 47.916282176971436 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 1.9683704376220703 seconds
# Jaccard graph constructed in 16.489983320236206 seconds
# Wrote graph to binary file in 1.1344375610351562 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.584099
# After 2 runs, maximum modularity is Q = 0.586707
# After 3 runs, maximum modularity is Q = 0.590906
# After 6 runs, maximum modularity is Q = 0.593482
# Louvain completed 26 runs in 17.379469871520996 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 51.68450665473938 seconds
# Finish initialization of MUSE
# epoch: 0, 	 total loss: 698.54163,	 reconstruction loss: 631.62561,	 sparse penalty: 0.27161,	 x triplet loss: 6.56608,	 y triplet loss: 6.54551
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 1.5577175617218018 seconds
# Jaccard graph constructed in 17.191354036331177 seconds
# Wrote graph to binary file in 1.0492985248565674 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.851778
# After 5 runs, maximum modularity is Q = 0.853024
# Louvain completed 25 runs in 12.462869882583618 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 47.52842998504639 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 2.0547478199005127 seconds
# Jaccard graph constructed in 17.968353033065796 seconds
# Wrote graph to binary file in 1.0255208015441895 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.583948
# After 2 runs, maximum modularity is Q = 0.597113
# Louvain completed 22 runs in 12.974189043045044 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 49.240800619125366 seconds
# epoch: 50, 	 total loss: 696.49078,	 reconstruction loss: 630.35724,	 sparse penalty: 0.24893,	 x triplet loss: 6.50309,	 y triplet loss: 6.47469
# epoch: 100, 	 total loss: 695.98621,	 reconstruction loss: 630.29950,	 sparse penalty: 0.22639,	 x triplet loss: 6.46891,	 y triplet loss: 6.44204
# epoch: 150, 	 total loss: 694.84955,	 reconstruction loss: 629.52625,	 sparse penalty: 0.20853,	 x triplet loss: 6.44166,	 y triplet loss: 6.41446
# epoch: 200, 	 total loss: 693.36359,	 reconstruction loss: 628.29950,	 sparse penalty: 0.19559,	 x triplet loss: 6.42180,	 y triplet loss: 6.39542
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 1.8934121131896973 seconds
# Jaccard graph constructed in 18.35091280937195 seconds
# Wrote graph to binary file in 1.189012050628662 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.840774
# After 2 runs, maximum modularity is Q = 0.843029
# Louvain completed 22 runs in 11.482810735702515 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 48.548171281814575 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 1.650810718536377 seconds
# Jaccard graph constructed in 18.437719106674194 seconds
# Wrote graph to binary file in 1.0500280857086182 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.587704
# After 2 runs, maximum modularity is Q = 0.600495
# Louvain completed 22 runs in 13.320550680160522 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 50.4498872756958 seconds
# epoch: 250, 	 total loss: 692.83710,	 reconstruction loss: 628.00220,	 sparse penalty: 0.18733,	 x triplet loss: 6.39944,	 y triplet loss: 6.38021
# epoch: 300, 	 total loss: 692.02014,	 reconstruction loss: 627.36847,	 sparse penalty: 0.17829,	 x triplet loss: 6.38452,	 y triplet loss: 6.36752
# epoch: 350, 	 total loss: 691.51038,	 reconstruction loss: 627.02075,	 sparse penalty: 0.16958,	 x triplet loss: 6.37264,	 y triplet loss: 6.35570
# epoch: 400, 	 total loss: 690.40100,	 reconstruction loss: 626.04254,	 sparse penalty: 0.16253,	 x triplet loss: 6.36296,	 y triplet loss: 6.34619
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 1.8459908962249756 seconds
# Jaccard graph constructed in 19.002406120300293 seconds
# Wrote graph to binary file in 1.1095795631408691 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.834358
# After 4 runs, maximum modularity is Q = 0.835439
# Louvain completed 24 runs in 12.862164497375488 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 50.88849878311157 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 1.9526269435882568 seconds
# Jaccard graph constructed in 19.027119159698486 seconds
# Wrote graph to binary file in 0.902019739151001 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.599316
# After 2 runs, maximum modularity is Q = 0.602648
# Louvain completed 22 runs in 13.441787004470825 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 52.042486906051636 seconds
# epoch: 450, 	 total loss: 689.63818,	 reconstruction loss: 625.41699,	 sparse penalty: 0.15703,	 x triplet loss: 6.35114,	 y triplet loss: 6.33607
# ++++++++++ MUSE completed ++++++++++
# ++++++++++ MUSE for multi-modality single-cell analysis ++++++++++
# MUSE initialization
# epoch: 0, 	 total loss: 1606.09338,	 reconstruction loss: 1312.95593,	 sparse penalty: 58.62749
# epoch: 50, 	 total loss: 842.57745,	 reconstruction loss: 695.97327,	 sparse penalty: 29.32084
# epoch: 100, 	 total loss: 702.64392,	 reconstruction loss: 645.67090,	 sparse penalty: 11.39460
# epoch: 150, 	 total loss: 648.25824,	 reconstruction loss: 635.06744,	 sparse penalty: 2.63816
# epoch: 0, 	 total loss: 828.99902,	 reconstruction loss: 706.76984,	 sparse penalty: 0.39821,	 x triplet: 12.27159,	 y triplet: 11.77606
# epoch: 50, 	 total loss: 739.17108,	 reconstruction loss: 646.34583,	 sparse penalty: 0.56023,	 x triplet: 9.03799,	 y triplet: 8.96683
# epoch: 100, 	 total loss: 728.90759,	 reconstruction loss: 638.82251,	 sparse penalty: 0.46097,	 x triplet: 8.80785,	 y triplet: 8.74819
# epoch: 150, 	 total loss: 724.14014,	 reconstruction loss: 635.46613,	 sparse penalty: 0.39521,	 x triplet: 8.69480,	 y triplet: 8.64480
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 1.652343511581421 seconds
# Jaccard graph constructed in 19.76272940635681 seconds
# Wrote graph to binary file in 1.1718354225158691 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.856158
# After 3 runs, maximum modularity is Q = 0.857707
# Louvain completed 23 runs in 12.905921220779419 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 52.793827295303345 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 2.0187225341796875 seconds
# Jaccard graph constructed in 20.27552604675293 seconds
# Wrote graph to binary file in 1.0441274642944336 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.614035
# After 3 runs, maximum modularity is Q = 0.617016
# Louvain completed 23 runs in 13.589393377304077 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 54.11655139923096 seconds
# Finish initialization of MUSE
# epoch: 0, 	 total loss: 722.61365,	 reconstruction loss: 634.74023,	 sparse penalty: 0.34721,	 x triplet loss: 8.62587,	 y triplet loss: 8.60161
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 1.77207350730896 seconds
# Jaccard graph constructed in 20.163245677947998 seconds
# Wrote graph to binary file in 0.9287011623382568 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.855671
# After 16 runs, maximum modularity is Q = 0.857037
# Louvain completed 36 runs in 18.247780084609985 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 58.63438534736633 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 1.995678424835205 seconds
# Jaccard graph constructed in 20.385604858398438 seconds
# Wrote graph to binary file in 1.0516507625579834 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.616496
# After 4 runs, maximum modularity is Q = 0.618396
# After 18 runs, maximum modularity is Q = 0.619846
# Louvain completed 38 runs in 22.3458149433136 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 63.71144342422485 seconds
# epoch: 50, 	 total loss: 720.81671,	 reconstruction loss: 633.82330,	 sparse penalty: 0.32217,	 x triplet loss: 8.54693,	 y triplet loss: 8.52959
# epoch: 100, 	 total loss: 719.14532,	 reconstruction loss: 632.67163,	 sparse penalty: 0.29494,	 x triplet loss: 8.50803,	 y triplet loss: 8.49178
# epoch: 150, 	 total loss: 718.24255,	 reconstruction loss: 632.13770,	 sparse penalty: 0.27190,	 x triplet loss: 8.48273,	 y triplet loss: 8.46635
# epoch: 200, 	 total loss: 716.43335,	 reconstruction loss: 630.59247,	 sparse penalty: 0.25308,	 x triplet loss: 8.46595,	 y triplet loss: 8.44915
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 1.6749804019927979 seconds
# Jaccard graph constructed in 20.69106364250183 seconds
# Wrote graph to binary file in 1.065345287322998 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.850964
# After 2 runs, maximum modularity is Q = 0.852141
# Louvain completed 22 runs in 12.944136142730713 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 54.625481843948364 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 1.9952661991119385 seconds
# Jaccard graph constructed in 21.586841106414795 seconds
# Wrote graph to binary file in 1.0368258953094482 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.632378
# After 6 runs, maximum modularity is Q = 0.634578
# After 15 runs, maximum modularity is Q = 0.637574
# Louvain completed 35 runs in 21.126625061035156 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 64.21801114082336 seconds
# epoch: 250, 	 total loss: 715.52026,	 reconstruction loss: 629.91479,	 sparse penalty: 0.23588,	 x triplet loss: 8.45146,	 y triplet loss: 8.43375
# epoch: 300, 	 total loss: 714.45105,	 reconstruction loss: 629.03052,	 sparse penalty: 0.22315,	 x triplet loss: 8.43967,	 y triplet loss: 8.42128
# epoch: 350, 	 total loss: 713.81311,	 reconstruction loss: 628.55701,	 sparse penalty: 0.21294,	 x triplet loss: 8.42990,	 y triplet loss: 8.40839
# epoch: 400, 	 total loss: 712.31128,	 reconstruction loss: 627.21167,	 sparse penalty: 0.20409,	 x triplet loss: 8.41682,	 y triplet loss: 8.39901
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 1.8597643375396729 seconds
# Jaccard graph constructed in 21.128028392791748 seconds
# Wrote graph to binary file in 1.1586651802062988 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.846011
# After 2 runs, maximum modularity is Q = 0.847184
# After 3 runs, maximum modularity is Q = 0.848501
# After 22 runs, maximum modularity is Q = 0.849944
# Louvain completed 42 runs in 24.956156015396118 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 67.80096435546875 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 1.6838841438293457 seconds
# Jaccard graph constructed in 21.512765884399414 seconds
# Wrote graph to binary file in 1.040437936782837 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.632045
# After 2 runs, maximum modularity is Q = 0.635215
# Louvain completed 22 runs in 13.594372749328613 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 56.8606493473053 seconds
# epoch: 450, 	 total loss: 711.50800,	 reconstruction loss: 626.53149,	 sparse penalty: 0.19681,	 x triplet loss: 8.40501,	 y triplet loss: 8.39348
# ++++++++++ MUSE completed ++++++++++
# ++++++++++ MUSE for multi-modality single-cell analysis ++++++++++
# MUSE initialization
# epoch: 0, 	 total loss: 1505.95837,	 reconstruction loss: 1206.10010,	 sparse penalty: 59.97166
# epoch: 50, 	 total loss: 849.59875,	 reconstruction loss: 696.66925,	 sparse penalty: 30.58590
# epoch: 100, 	 total loss: 704.05798,	 reconstruction loss: 642.16956,	 sparse penalty: 12.37769
# epoch: 150, 	 total loss: 653.64343,	 reconstruction loss: 636.21930,	 sparse penalty: 3.48482
# epoch: 0, 	 total loss: 819.89404,	 reconstruction loss: 705.98853,	 sparse penalty: 1.02587,	 x triplet: 11.08246,	 y triplet: 10.67278
# epoch: 50, 	 total loss: 721.77490,	 reconstruction loss: 638.32819,	 sparse penalty: 0.53470,	 x triplet: 8.12541,	 y triplet: 8.02924
# epoch: 100, 	 total loss: 715.17731,	 reconstruction loss: 634.60352,	 sparse penalty: 0.40975,	 x triplet: 7.88570,	 y triplet: 7.81930
# epoch: 150, 	 total loss: 712.52002,	 reconstruction loss: 633.33099,	 sparse penalty: 0.33936,	 x triplet: 7.77704,	 y triplet: 7.72142
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 1.871521234512329 seconds
# Jaccard graph constructed in 22.450358390808105 seconds
# Wrote graph to binary file in 1.3596415519714355 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.861509
# After 3 runs, maximum modularity is Q = 0.863045
# Louvain completed 23 runs in 13.435770750045776 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 58.82409334182739 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 1.7841660976409912 seconds
# Jaccard graph constructed in 22.988632440567017 seconds
# Wrote graph to binary file in 0.9957499504089355 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.595291
# After 2 runs, maximum modularity is Q = 0.59752
# Louvain completed 22 runs in 14.579777002334595 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 60.192333936691284 seconds
# Finish initialization of MUSE
# epoch: 0, 	 total loss: 710.06354,	 reconstruction loss: 631.71185,	 sparse penalty: 0.29834,	 x triplet loss: 7.70236,	 y triplet loss: 7.66963
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 1.7735283374786377 seconds
# Jaccard graph constructed in 23.782610177993774 seconds
# Wrote graph to binary file in 1.2412664890289307 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.8629
# Louvain completed 21 runs in 11.827831506729126 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 60.136874198913574 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 14.615305662155151 seconds
# Jaccard graph constructed in 24.610965728759766 seconds
# Wrote graph to binary file in 1.430281400680542 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.590862
# After 3 runs, maximum modularity is Q = 0.599115
# After 8 runs, maximum modularity is Q = 0.600256
# After 13 runs, maximum modularity is Q = 0.6026
# Louvain completed 33 runs in 23.279808282852173 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 84.77999806404114 seconds
# epoch: 50, 	 total loss: 708.70990,	 reconstruction loss: 631.13123,	 sparse penalty: 0.28178,	 x triplet loss: 7.62906,	 y triplet loss: 7.60489
# epoch: 100, 	 total loss: 706.86859,	 reconstruction loss: 629.74835,	 sparse penalty: 0.25857,	 x triplet loss: 7.59411,	 y triplet loss: 7.57138
# epoch: 150, 	 total loss: 706.21167,	 reconstruction loss: 629.43024,	 sparse penalty: 0.23961,	 x triplet loss: 7.56812,	 y triplet loss: 7.54856
# epoch: 200, 	 total loss: 705.50378,	 reconstruction loss: 628.98663,	 sparse penalty: 0.22400,	 x triplet loss: 7.54939,	 y triplet loss: 7.53004
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 1.9460878372192383 seconds
# Jaccard graph constructed in 25.355312824249268 seconds
# Wrote graph to binary file in 1.0544145107269287 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.853203
# After 7 runs, maximum modularity is Q = 0.854254
# Louvain completed 27 runs in 17.616756200790405 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 70.68063163757324 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 39.68047761917114 seconds
# Jaccard graph constructed in 27.042834758758545 seconds
# Wrote graph to binary file in 1.039799451828003 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.599595
# After 3 runs, maximum modularity is Q = 0.606142
# Louvain completed 23 runs in 17.32654118537903 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 111.31317472457886 seconds
# epoch: 250, 	 total loss: 704.51996,	 reconstruction loss: 628.20703,	 sparse penalty: 0.20882,	 x triplet loss: 7.53952,	 y triplet loss: 7.51423
# epoch: 300, 	 total loss: 704.61743,	 reconstruction loss: 628.47937,	 sparse penalty: 0.19899,	 x triplet loss: 7.52580,	 y triplet loss: 7.50281
# epoch: 350, 	 total loss: 702.89240,	 reconstruction loss: 626.90247,	 sparse penalty: 0.19003,	 x triplet loss: 7.51439,	 y triplet loss: 7.49358
# epoch: 400, 	 total loss: 702.76593,	 reconstruction loss: 626.92102,	 sparse penalty: 0.18276,	 x triplet loss: 7.50440,	 y triplet loss: 7.48182
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 57.99834656715393 seconds
# Jaccard graph constructed in 25.82192873954773 seconds
# Wrote graph to binary file in 1.0400006771087646 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.838735
# After 2 runs, maximum modularity is Q = 0.839799
# Louvain completed 22 runs in 14.349984169006348 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 120.67132139205933 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 52.56972813606262 seconds
# Jaccard graph constructed in 25.993175983428955 seconds
# Wrote graph to binary file in 1.0361874103546143 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.602826
# After 4 runs, maximum modularity is Q = 0.607801
# After 12 runs, maximum modularity is Q = 0.611082
# Louvain completed 32 runs in 22.41238236427307 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 124.90429329872131 seconds
# epoch: 450, 	 total loss: 701.68268,	 reconstruction loss: 625.96307,	 sparse penalty: 0.17759,	 x triplet loss: 7.49240,	 y triplet loss: 7.47394
# ++++++++++ MUSE completed ++++++++++
